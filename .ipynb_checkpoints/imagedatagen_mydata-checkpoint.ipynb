# %%
import PIL

# %%
import pandas as pd

# %%
#import cv2
import numpy as np
import glob
import tensorflow as tf
import tensorflow
from tensorflow.keras import datasets, layers, models

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
#from tensorflow.keras.utils import np_utils
from tensorflow.keras import utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import SGD
import tensorflow.keras
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt

# %%
vehicle_images = glob.glob('./vehicle_chips2/*/*.png')

# %%
vehicle_images
# Out:
# ['./vehicle_chips2\\set1\\vehicle_chip_0.png',
#  './vehicle_chips2\\set1\\vehicle_chip_1.png',
#  './vehicle_chips2\\set1\\vehicle_chip_10.png',
#  './vehicle_chips2\\set1\\vehicle_chip_100.png',
#  './vehicle_chips2\\set1\\vehicle_chip_101.png',
#  './vehicle_chips2\\set1\\vehicle_chip_102.png',
#  './vehicle_chips2\\set1\\vehicle_chip_103.png',
#  './vehicle_chips2\\set1\\vehicle_chip_104.png',
#  './vehicle_chips2\\set1\\vehicle_chip_105.png',
#  './vehicle_chips2\\set1\\vehicle_chip_106.png',
#  './vehicle_chips2\\set1\\vehicle_chip_107.png',
#  './vehicle_chips2\\set1\\vehicle_chip_108.png',
#  './vehicle_chips2\\set1\\vehicle_chip_109.png',
#  './vehicle_chips2\\set1\\vehicle_chip_11.png',
#  './vehicle_chips2\\set1\\vehicle_chip_110.png',
#  './vehicle_chips2\\set1\\vehicle_chip_111.png',
#  './vehicle_chips2\\set1\\vehicle_chip_112.png',
#  './vehicle_chips2\\set1\\vehicle_chip_113.png',
#  './vehicle_chips2\\set1\\vehicle_chip_114.png',
#  './vehicle_chips2\\set1\\vehicle_chip_115.png',
#  './vehicle_chips2\\set1\\vehicle_chip_116.png',
#  './vehicle_chips2\\set1\\vehicle_chip_117.png',
#  './vehicle_chips2\\set1\\vehicle_chip_118.png',
#  './vehicle_chips2\\set1\\vehicle_chip_119.png',
#  './vehicle_chips2\\set1\\vehicle_chip_12.png',
#  './vehicle_chips2\\set1\\vehicle_chip_120.png',
#  './vehicle_chips2\\set1\\vehicle_chip_121.png',
#  './vehicle_chips2\\set1\\vehicle_chip_122.png',
#  './vehicle_chips2\\set1\\vehicle_chip_123.png',
#  './vehicle_chips2\\set1\\vehicle_chip_124.png',
#  './vehicle_chips2\\set1\\vehicle_chip_125.png',
#  './vehicle_chips2\\set1\\vehicle_chip_126.png',
#  './vehicle_chips2\\set1\\vehicle_chip_127.png',
#  './vehicle_chips2\\set1\\vehicle_chip_128.png',
#  './vehicle_chips2\\set1\\vehicle_chip_129.png',
#  './vehicle_chips2\\set1\\vehicle_chip_13.png',
#  './vehicle_chips2\\set1\\vehicle_chip_130.png',
#  './vehicle_chips2\\set1\\vehicle_chip_131.png',
#  './vehicle_chips2\\set1\\vehicle_chip_132.png',
#  './vehicle_chips2\\set1\\vehicle_chip_133.png',
#  './vehicle_chips2\\set1\\vehicle_chip_134.png',
#  './vehicle_chips2\\set1\\vehicle_chip_135.png',
#  './vehicle_chips2\\set1\\vehicle_chip_136.png',
#  './vehicle_chips2\\set1\\vehicle_chip_137.png',
#  './vehicle_chips2\\set1\\vehicle_chip_138.png',
#  './vehicle_chips2\\set1\\vehicle_chip_139.png',
#  './vehicle_chips2\\set1\\vehicle_chip_14.png',
#  './vehicle_chips2\\set1\\vehicle_chip_140.png',
#  './vehicle_chips2\\set1\\vehicle_chip_141.png',
#  './vehicle_chips2\\set1\\vehicle_chip_142.png',
#  './vehicle_chips2\\set1\\vehicle_chip_143.png',
#  './vehicle_chips2\\set1\\vehicle_chip_144.png',
#  './vehicle_chips2\\set1\\vehicle_chip_145.png',
#  './vehicle_chips2\\set1\\vehicle_chip_146.png',
#  './vehicle_chips2\\set1\\vehicle_chip_147.png',
#  './vehicle_chips2\\set1\\vehicle_chip_148.png',
#  './vehicle_chips2\\set1\\vehicle_chip_149.png',
#  './vehicle_chips2\\set1\\vehicle_chip_15.png',
#  './vehicle_chips2\\set1\\vehicle_chip_150.png',
#  './vehicle_chips2\\set1\\vehicle_chip_151.png',
#  './vehicle_chips2\\set1\\vehicle_chip_152.png',
#  './vehicle_chips2\\set1\\vehicle_chip_153.png',
#  './vehicle_chips2\\set1\\vehicle_chip_154.png',
#  './vehicle_chips2\\set1\\vehicle_chip_155.png',
#  './vehicle_chips2\\set1\\vehicle_chip_156.png',
#  './vehicle_chips2\\set1\\vehicle_chip_157.png',
#  './vehicle_chips2\\set1\\vehicle_chip_158.png',
#  './vehicle_chips2\\set1\\vehicle_chip_159.png',
#  './vehicle_chips2\\set1\\vehicle_chip_16.png',
#  './vehicle_chips2\\set1\\vehicle_chip_160.png',
#  './vehicle_chips2\\set1\\vehicle_chip_161.png',
#  './vehicle_chips2\\set1\\vehicle_chip_162.png',
#  './vehicle_chips2\\set1\\vehicle_chip_163.png',
#  './vehicle_chips2\\set1\\vehicle_chip_164.png',
#  './vehicle_chips2\\set1\\vehicle_chip_165.png',
#  './vehicle_chips2\\set1\\vehicle_chip_166.png',
#  './vehicle_chips2\\set1\\vehicle_chip_167.png',
#  './vehicle_chips2\\set1\\vehicle_chip_168.png',
#  './vehicle_chips2\\set1\\vehicle_chip_169.png',
#  './vehicle_chips2\\set1\\vehicle_chip_17.png',
#  './vehicle_chips2\\set1\\vehicle_chip_170.png',
#  './vehicle_chips2\\set1\\vehicle_chip_171.png',
#  './vehicle_chips2\\set1\\vehicle_chip_172.png',
#  './vehicle_chips2\\set1\\vehicle_chip_173.png',
#  './vehicle_chips2\\set1\\vehicle_chip_174.png',
#  './vehicle_chips2\\set1\\vehicle_chip_175.png',
#  './vehicle_chips2\\set1\\vehicle_chip_176.png',
#  './vehicle_chips2\\set1\\vehicle_chip_177.png',
#  './vehicle_chips2\\set1\\vehicle_chip_178.png',
#  './vehicle_chips2\\set1\\vehicle_chip_179.png',
#  './vehicle_chips2\\set1\\vehicle_chip_18.png',
#  './vehicle_chips2\\set1\\vehicle_chip_180.png',
#  './vehicle_chips2\\set1\\vehicle_chip_181.png',
#  './vehicle_chips2\\set1\\vehicle_chip_182.png',
#  './vehicle_chips2\\set1\\vehicle_chip_183.png',
#  './vehicle_chips2\\set1\\vehicle_chip_184.png',
#  './vehicle_chips2\\set1\\vehicle_chip_185.png',
#  './vehicle_chips2\\set1\\vehicle_chip_186.png',
#  './vehicle_chips2\\set1\\vehicle_chip_187.png',
#  './vehicle_chips2\\set1\\vehicle_chip_188.png',
#  './vehicle_chips2\\set1\\vehicle_chip_189.png',
#  './vehicle_chips2\\set1\\vehicle_chip_19.png',
#  './vehicle_chips2\\set1\\vehicle_chip_190.png',
#  './vehicle_chips2\\set1\\vehicle_chip_191.png',
#  './vehicle_chips2\\set1\\vehicle_chip_192.png',
#  './vehicle_chips2\\set1\\vehicle_chip_193.png',
#  './vehicle_chips2\\set1\\vehicle_chip_194.png',
#  './vehicle_chips2\\set1\\vehicle_chip_195.png',
#  './vehicle_chips2\\set1\\vehicle_chip_196.png',
#  './vehicle_chips2\\set1\\vehicle_chip_197.png',
#  './vehicle_chips2\\set1\\vehicle_chip_198.png',
#  './vehicle_chips2\\set1\\vehicle_chip_199.png',
#  './vehicle_chips2\\set1\\vehicle_chip_2.png',
#  './vehicle_chips2\\set1\\vehicle_chip_20.png',
#  './vehicle_chips2\\set1\\vehicle_chip_200.png',
#  './vehicle_chips2\\set1\\vehicle_chip_201.png',
#  './vehicle_chips2\\set1\\vehicle_chip_202.png',
#  './vehicle_chips2\\set1\\vehicle_chip_203.png',
#  './vehicle_chips2\\set1\\vehicle_chip_204.png',
#  './vehicle_chips2\\set1\\vehicle_chip_205.png',
#  './vehicle_chips2\\set1\\vehicle_chip_206.png',
#  './vehicle_chips2\\set1\\vehicle_chip_207.png',
#  './vehicle_chips2\\set1\\vehicle_chip_208.png',
#  './vehicle_chips2\\set1\\vehicle_chip_209.png',
#  './vehicle_chips2\\set1\\vehicle_chip_21.png',
#  './vehicle_chips2\\set1\\vehicle_chip_210.png',
#  './vehicle_chips2\\set1\\vehicle_chip_211.png',
#  './vehicle_chips2\\set1\\vehicle_chip_212.png',
#  './vehicle_chips2\\set1\\vehicle_chip_213.png',
#  './vehicle_chips2\\set1\\vehicle_chip_214.png',
#  './vehicle_chips2\\set1\\vehicle_chip_215.png',
#  './vehicle_chips2\\set1\\vehicle_chip_216.png',
#  './vehicle_chips2\\set1\\vehicle_chip_217.png',
#  './vehicle_chips2\\set1\\vehicle_chip_218.png',
#  './vehicle_chips2\\set1\\vehicle_chip_219.png',
#  './vehicle_chips2\\set1\\vehicle_chip_22.png',
#  './vehicle_chips2\\set1\\vehicle_chip_220.png',
#  './vehicle_chips2\\set1\\vehicle_chip_221.png',
#  './vehicle_chips2\\set1\\vehicle_chip_222.png',
#  './vehicle_chips2\\set1\\vehicle_chip_223.png',
#  './vehicle_chips2\\set1\\vehicle_chip_224.png',
#  './vehicle_chips2\\set1\\vehicle_chip_225.png',
#  './vehicle_chips2\\set1\\vehicle_chip_226.png',
#  './vehicle_chips2\\set1\\vehicle_chip_227.png',
#  './vehicle_chips2\\set1\\vehicle_chip_228.png',
#  './vehicle_chips2\\set1\\vehicle_chip_229.png',
#  './vehicle_chips2\\set1\\vehicle_chip_23.png',
#  './vehicle_chips2\\set1\\vehicle_chip_230.png',
#  './vehicle_chips2\\set1\\vehicle_chip_231.png',
#  './vehicle_chips2\\set1\\vehicle_chip_232.png',
#  './vehicle_chips2\\set1\\vehicle_chip_233.png',
#  './vehicle_chips2\\set1\\vehicle_chip_234.png',
#  './vehicle_chips2\\set1\\vehicle_chip_235.png',
#  './vehicle_chips2\\set1\\vehicle_chip_236.png',
#  './vehicle_chips2\\set1\\vehicle_chip_237.png',
#  './vehicle_chips2\\set1\\vehicle_chip_238.png',
#  './vehicle_chips2\\set1\\vehicle_chip_239.png',
#  './vehicle_chips2\\set1\\vehicle_chip_24.png',
#  './vehicle_chips2\\set1\\vehicle_chip_240.png',
#  './vehicle_chips2\\set1\\vehicle_chip_241.png',
#  './vehicle_chips2\\set1\\vehicle_chip_242.png',
#  './vehicle_chips2\\set1\\vehicle_chip_243.png',
#  './vehicle_chips2\\set1\\vehicle_chip_244.png',
#  './vehicle_chips2\\set1\\vehicle_chip_245.png',
#  './vehicle_chips2\\set1\\vehicle_chip_246.png',
#  './vehicle_chips2\\set1\\vehicle_chip_247.png',
#  './vehicle_chips2\\set1\\vehicle_chip_248.png',
#  './vehicle_chips2\\set1\\vehicle_chip_249.png',
#  './vehicle_chips2\\set1\\vehicle_chip_25.png',
#  './vehicle_chips2\\set1\\vehicle_chip_250.png',
#  './vehicle_chips2\\set1\\vehicle_chip_251.png',
#  './vehicle_chips2\\set1\\vehicle_chip_252.png',
#  './vehicle_chips2\\set1\\vehicle_chip_253.png',
#  './vehicle_chips2\\set1\\vehicle_chip_254.png',
#  './vehicle_chips2\\set1\\vehicle_chip_255.png',
#  './vehicle_chips2\\set1\\vehicle_chip_256.png',
#  './vehicle_chips2\\set1\\vehicle_chip_257.png',
#  './vehicle_chips2\\set1\\vehicle_chip_258.png',
#  './vehicle_chips2\\set1\\vehicle_chip_259.png',
#  './vehicle_chips2\\set1\\vehicle_chip_26.png',
#  './vehicle_chips2\\set1\\vehicle_chip_260.png',
#  './vehicle_chips2\\set1\\vehicle_chip_261.png',
#  './vehicle_chips2\\set1\\vehicle_chip_262.png',
#  './vehicle_chips2\\set1\\vehicle_chip_263.png',
#  './vehicle_chips2\\set1\\vehicle_chip_264.png',
#  './vehicle_chips2\\set1\\vehicle_chip_265.png',
#  './vehicle_chips2\\set1\\vehicle_chip_266.png',
#  './vehicle_chips2\\set1\\vehicle_chip_267.png',
#  './vehicle_chips2\\set1\\vehicle_chip_268.png',
#  './vehicle_chips2\\set1\\vehicle_chip_269.png',
#  './vehicle_chips2\\set1\\vehicle_chip_27.png',
#  './vehicle_chips2\\set1\\vehicle_chip_270.png',
#  './vehicle_chips2\\set1\\vehicle_chip_271.png',
#  './vehicle_chips2\\set1\\vehicle_chip_272.png',
#  './vehicle_chips2\\set1\\vehicle_chip_273.png',
#  './vehicle_chips2\\set1\\vehicle_chip_274.png',
#  './vehicle_chips2\\set1\\vehicle_chip_275.png',
#  './vehicle_chips2\\set1\\vehicle_chip_276.png',
#  './vehicle_chips2\\set1\\vehicle_chip_277.png',
#  './vehicle_chips2\\set1\\vehicle_chip_278.png',
#  './vehicle_chips2\\set1\\vehicle_chip_279.png',
#  './vehicle_chips2\\set1\\vehicle_chip_28.png',
#  './vehicle_chips2\\set1\\vehicle_chip_280.png',
#  './vehicle_chips2\\set1\\vehicle_chip_281.png',
#  './vehicle_chips2\\set1\\vehicle_chip_282.png',
#  './vehicle_chips2\\set1\\vehicle_chip_283.png',
#  './vehicle_chips2\\set1\\vehicle_chip_284.png',
#  './vehicle_chips2\\set1\\vehicle_chip_285.png',
#  './vehicle_chips2\\set1\\vehicle_chip_286.png',
#  './vehicle_chips2\\set1\\vehicle_chip_287.png',
#  './vehicle_chips2\\set1\\vehicle_chip_288.png',
#  './vehicle_chips2\\set1\\vehicle_chip_289.png',
#  './vehicle_chips2\\set1\\vehicle_chip_29.png',
#  './vehicle_chips2\\set1\\vehicle_chip_290.png',
#  './vehicle_chips2\\set1\\vehicle_chip_291.png',
#  './vehicle_chips2\\set1\\vehicle_chip_292.png',
#  './vehicle_chips2\\set1\\vehicle_chip_293.png',
#  './vehicle_chips2\\set1\\vehicle_chip_294.png',
#  './vehicle_chips2\\set1\\vehicle_chip_295.png',
#  './vehicle_chips2\\set1\\vehicle_chip_296.png',
#  './vehicle_chips2\\set1\\vehicle_chip_297.png',
#  './vehicle_chips2\\set1\\vehicle_chip_298.png',
#  './vehicle_chips2\\set1\\vehicle_chip_299.png',
#  './vehicle_chips2\\set1\\vehicle_chip_3.png',
#  './vehicle_chips2\\set1\\vehicle_chip_30.png',
#  './vehicle_chips2\\set1\\vehicle_chip_300.png',
#  './vehicle_chips2\\set1\\vehicle_chip_301.png',
#  './vehicle_chips2\\set1\\vehicle_chip_302.png',
#  './vehicle_chips2\\set1\\vehicle_chip_303.png',
#  './vehicle_chips2\\set1\\vehicle_chip_304.png',
#  './vehicle_chips2\\set1\\vehicle_chip_305.png',
#  './vehicle_chips2\\set1\\vehicle_chip_306.png',
#  './vehicle_chips2\\set1\\vehicle_chip_307.png',
#  './vehicle_chips2\\set1\\vehicle_chip_308.png',
#  './vehicle_chips2\\set1\\vehicle_chip_309.png',
#  './vehicle_chips2\\set1\\vehicle_chip_31.png',
#  './vehicle_chips2\\set1\\vehicle_chip_310.png',
#  './vehicle_chips2\\set1\\vehicle_chip_311.png',
#  './vehicle_chips2\\set1\\vehicle_chip_312.png',
#  './vehicle_chips2\\set1\\vehicle_chip_313.png',
#  './vehicle_chips2\\set1\\vehicle_chip_314.png',
#  './vehicle_chips2\\set1\\vehicle_chip_315.png',
#  './vehicle_chips2\\set1\\vehicle_chip_316.png',
#  './vehicle_chips2\\set1\\vehicle_chip_317.png',
#  './vehicle_chips2\\set1\\vehicle_chip_318.png',
#  './vehicle_chips2\\set1\\vehicle_chip_319.png',
#  './vehicle_chips2\\set1\\vehicle_chip_32.png',
#  './vehicle_chips2\\set1\\vehicle_chip_320.png',
#  './vehicle_chips2\\set1\\vehicle_chip_321.png',
#  './vehicle_chips2\\set1\\vehicle_chip_322.png',
#  './vehicle_chips2\\set1\\vehicle_chip_323.png',
#  './vehicle_chips2\\set1\\vehicle_chip_324.png',
#  './vehicle_chips2\\set1\\vehicle_chip_325.png',
#  './vehicle_chips2\\set1\\vehicle_chip_326.png',
#  './vehicle_chips2\\set1\\vehicle_chip_327.png',
#  './vehicle_chips2\\set1\\vehicle_chip_328.png',
#  './vehicle_chips2\\set1\\vehicle_chip_329.png',
#  './vehicle_chips2\\set1\\vehicle_chip_33.png',
#  './vehicle_chips2\\set1\\vehicle_chip_330.png',
#  './vehicle_chips2\\set1\\vehicle_chip_331.png',
#  './vehicle_chips2\\set1\\vehicle_chip_332.png',
#  './vehicle_chips2\\set1\\vehicle_chip_333.png',
#  './vehicle_chips2\\set1\\vehicle_chip_334.png',
#  './vehicle_chips2\\set1\\vehicle_chip_335.png',
#  './vehicle_chips2\\set1\\vehicle_chip_336.png',
#  './vehicle_chips2\\set1\\vehicle_chip_337.png',
#  './vehicle_chips2\\set1\\vehicle_chip_338.png',
#  './vehicle_chips2\\set1\\vehicle_chip_339.png',
#  './vehicle_chips2\\set1\\vehicle_chip_34.png',
#  './vehicle_chips2\\set1\\vehicle_chip_340.png',
#  './vehicle_chips2\\set1\\vehicle_chip_341.png',
#  './vehicle_chips2\\set1\\vehicle_chip_342.png',
#  './vehicle_chips2\\set1\\vehicle_chip_343.png',
#  './vehicle_chips2\\set1\\vehicle_chip_344.png',
#  './vehicle_chips2\\set1\\vehicle_chip_345.png',
#  './vehicle_chips2\\set1\\vehicle_chip_346.png',
#  './vehicle_chips2\\set1\\vehicle_chip_347.png',
#  './vehicle_chips2\\set1\\vehicle_chip_348.png',
#  './vehicle_chips2\\set1\\vehicle_chip_349.png',
#  './vehicle_chips2\\set1\\vehicle_chip_35.png',
#  './vehicle_chips2\\set1\\vehicle_chip_350.png',
#  './vehicle_chips2\\set1\\vehicle_chip_351.png',
#  './vehicle_chips2\\set1\\vehicle_chip_352.png',
#  './vehicle_chips2\\set1\\vehicle_chip_353.png',
#  './vehicle_chips2\\set1\\vehicle_chip_354.png',
#  './vehicle_chips2\\set1\\vehicle_chip_355.png',
#  './vehicle_chips2\\set1\\vehicle_chip_356.png',
#  './vehicle_chips2\\set1\\vehicle_chip_357.png',
#  './vehicle_chips2\\set1\\vehicle_chip_358.png',
#  './vehicle_chips2\\set1\\vehicle_chip_359.png',
#  './vehicle_chips2\\set1\\vehicle_chip_36.png',
#  './vehicle_chips2\\set1\\vehicle_chip_360.png',
#  './vehicle_chips2\\set1\\vehicle_chip_361.png',
#  './vehicle_chips2\\set1\\vehicle_chip_362.png',
#  './vehicle_chips2\\set1\\vehicle_chip_363.png',
#  './vehicle_chips2\\set1\\vehicle_chip_364.png',
#  './vehicle_chips2\\set1\\vehicle_chip_365.png',
#  './vehicle_chips2\\set1\\vehicle_chip_366.png',
#  './vehicle_chips2\\set1\\vehicle_chip_367.png',
#  './vehicle_chips2\\set1\\vehicle_chip_368.png',
#  './vehicle_chips2\\set1\\vehicle_chip_369.png',
#  './vehicle_chips2\\set1\\vehicle_chip_37.png',
#  './vehicle_chips2\\set1\\vehicle_chip_370.png',
#  './vehicle_chips2\\set1\\vehicle_chip_371.png',
#  './vehicle_chips2\\set1\\vehicle_chip_372.png',
#  './vehicle_chips2\\set1\\vehicle_chip_373.png',
#  './vehicle_chips2\\set1\\vehicle_chip_374.png',
#  './vehicle_chips2\\set1\\vehicle_chip_375.png',
#  './vehicle_chips2\\set1\\vehicle_chip_376.png',
#  './vehicle_chips2\\set1\\vehicle_chip_377.png',
#  './vehicle_chips2\\set1\\vehicle_chip_378.png',
#  './vehicle_chips2\\set1\\vehicle_chip_379.png',
#  './vehicle_chips2\\set1\\vehicle_chip_38.png',
#  './vehicle_chips2\\set1\\vehicle_chip_380.png',
#  './vehicle_chips2\\set1\\vehicle_chip_381.png',
#  './vehicle_chips2\\set1\\vehicle_chip_382.png',
#  './vehicle_chips2\\set1\\vehicle_chip_383.png',
#  './vehicle_chips2\\set1\\vehicle_chip_384.png',
#  './vehicle_chips2\\set1\\vehicle_chip_385.png',
#  './vehicle_chips2\\set1\\vehicle_chip_386.png',
#  './vehicle_chips2\\set1\\vehicle_chip_387.png',
#  './vehicle_chips2\\set1\\vehicle_chip_388.png',
#  './vehicle_chips2\\set1\\vehicle_chip_389.png',
#  './vehicle_chips2\\set1\\vehicle_chip_39.png',
#  './vehicle_chips2\\set1\\vehicle_chip_390.png',
#  './vehicle_chips2\\set1\\vehicle_chip_391.png',
#  './vehicle_chips2\\set1\\vehicle_chip_392.png',
#  './vehicle_chips2\\set1\\vehicle_chip_393.png',
#  './vehicle_chips2\\set1\\vehicle_chip_394.png',
#  './vehicle_chips2\\set1\\vehicle_chip_395.png',
#  './vehicle_chips2\\set1\\vehicle_chip_396.png',
#  './vehicle_chips2\\set1\\vehicle_chip_397.png',
#  './vehicle_chips2\\set1\\vehicle_chip_398.png',
#  './vehicle_chips2\\set1\\vehicle_chip_399.png',
#  './vehicle_chips2\\set1\\vehicle_chip_4.png',
#  './vehicle_chips2\\set1\\vehicle_chip_40.png',
#  './vehicle_chips2\\set1\\vehicle_chip_400.png',
#  './vehicle_chips2\\set1\\vehicle_chip_401.png',
#  './vehicle_chips2\\set1\\vehicle_chip_402.png',
#  './vehicle_chips2\\set1\\vehicle_chip_403.png',
#  './vehicle_chips2\\set1\\vehicle_chip_404.png',
#  './vehicle_chips2\\set1\\vehicle_chip_405.png',
#  './vehicle_chips2\\set1\\vehicle_chip_406.png',
#  './vehicle_chips2\\set1\\vehicle_chip_407.png',
#  './vehicle_chips2\\set1\\vehicle_chip_408.png',
#  './vehicle_chips2\\set1\\vehicle_chip_409.png',
#  './vehicle_chips2\\set1\\vehicle_chip_41.png',
#  './vehicle_chips2\\set1\\vehicle_chip_410.png',
#  './vehicle_chips2\\set1\\vehicle_chip_411.png',
#  './vehicle_chips2\\set1\\vehicle_chip_412.png',
#  './vehicle_chips2\\set1\\vehicle_chip_413.png',
#  './vehicle_chips2\\set1\\vehicle_chip_414.png',
#  './vehicle_chips2\\set1\\vehicle_chip_415.png',
#  './vehicle_chips2\\set1\\vehicle_chip_416.png',
#  './vehicle_chips2\\set1\\vehicle_chip_417.png',
#  './vehicle_chips2\\set1\\vehicle_chip_418.png',
#  './vehicle_chips2\\set1\\vehicle_chip_419.png',
#  './vehicle_chips2\\set1\\vehicle_chip_42.png',
#  './vehicle_chips2\\set1\\vehicle_chip_420.png',
#  './vehicle_chips2\\set1\\vehicle_chip_421.png',
#  './vehicle_chips2\\set1\\vehicle_chip_422.png',
#  './vehicle_chips2\\set1\\vehicle_chip_423.png',
#  './vehicle_chips2\\set1\\vehicle_chip_424.png',
#  './vehicle_chips2\\set1\\vehicle_chip_425.png',
#  './vehicle_chips2\\set1\\vehicle_chip_426.png',
#  './vehicle_chips2\\set1\\vehicle_chip_427.png',
#  './vehicle_chips2\\set1\\vehicle_chip_428.png',
#  './vehicle_chips2\\set1\\vehicle_chip_429.png',
#  './vehicle_chips2\\set1\\vehicle_chip_43.png',
#  './vehicle_chips2\\set1\\vehicle_chip_430.png',
#  './vehicle_chips2\\set1\\vehicle_chip_431.png',
#  './vehicle_chips2\\set1\\vehicle_chip_432.png',
#  './vehicle_chips2\\set1\\vehicle_chip_433.png',
#  './vehicle_chips2\\set1\\vehicle_chip_434.png',
#  './vehicle_chips2\\set1\\vehicle_chip_435.png',
#  './vehicle_chips2\\set1\\vehicle_chip_436.png',
#  './vehicle_chips2\\set1\\vehicle_chip_437.png',
#  './vehicle_chips2\\set1\\vehicle_chip_438.png',
#  './vehicle_chips2\\set1\\vehicle_chip_439.png',
#  './vehicle_chips2\\set1\\vehicle_chip_44.png',
#  './vehicle_chips2\\set1\\vehicle_chip_440.png',
#  './vehicle_chips2\\set1\\vehicle_chip_441.png',
#  './vehicle_chips2\\set1\\vehicle_chip_442.png',
#  './vehicle_chips2\\set1\\vehicle_chip_443.png',
#  './vehicle_chips2\\set1\\vehicle_chip_444.png',
#  './vehicle_chips2\\set1\\vehicle_chip_445.png',
#  './vehicle_chips2\\set1\\vehicle_chip_446.png',
#  './vehicle_chips2\\set1\\vehicle_chip_447.png',
#  './vehicle_chips2\\set1\\vehicle_chip_448.png',
#  './vehicle_chips2\\set1\\vehicle_chip_449.png',
#  './vehicle_chips2\\set1\\vehicle_chip_45.png',
#  './vehicle_chips2\\set1\\vehicle_chip_450.png',
#  './vehicle_chips2\\set1\\vehicle_chip_451.png',
#  './vehicle_chips2\\set1\\vehicle_chip_452.png',
#  './vehicle_chips2\\set1\\vehicle_chip_453.png',
#  './vehicle_chips2\\set1\\vehicle_chip_454.png',
#  './vehicle_chips2\\set1\\vehicle_chip_455.png',
#  './vehicle_chips2\\set1\\vehicle_chip_456.png',
#  './vehicle_chips2\\set1\\vehicle_chip_457.png',
#  './vehicle_chips2\\set1\\vehicle_chip_458.png',
#  './vehicle_chips2\\set1\\vehicle_chip_459.png',
#  './vehicle_chips2\\set1\\vehicle_chip_46.png',
#  './vehicle_chips2\\set1\\vehicle_chip_460.png',
#  './vehicle_chips2\\set1\\vehicle_chip_461.png',
#  './vehicle_chips2\\set1\\vehicle_chip_462.png',
#  './vehicle_chips2\\set1\\vehicle_chip_463.png',
#  './vehicle_chips2\\set1\\vehicle_chip_464.png',
#  './vehicle_chips2\\set1\\vehicle_chip_465.png',
#  './vehicle_chips2\\set1\\vehicle_chip_466.png',
#  './vehicle_chips2\\set1\\vehicle_chip_467.png',
#  './vehicle_chips2\\set1\\vehicle_chip_468.png',
#  './vehicle_chips2\\set1\\vehicle_chip_469.png',
#  './vehicle_chips2\\set1\\vehicle_chip_47.png',
#  './vehicle_chips2\\set1\\vehicle_chip_470.png',
#  './vehicle_chips2\\set1\\vehicle_chip_471.png',
#  './vehicle_chips2\\set1\\vehicle_chip_472.png',
#  './vehicle_chips2\\set1\\vehicle_chip_473.png',
#  './vehicle_chips2\\set1\\vehicle_chip_474.png',
#  './vehicle_chips2\\set1\\vehicle_chip_475.png',
#  './vehicle_chips2\\set1\\vehicle_chip_476.png',
#  './vehicle_chips2\\set1\\vehicle_chip_477.png',
#  './vehicle_chips2\\set1\\vehicle_chip_478.png',
#  './vehicle_chips2\\set1\\vehicle_chip_479.png',
#  './vehicle_chips2\\set1\\vehicle_chip_48.png',
#  './vehicle_chips2\\set1\\vehicle_chip_480.png',
#  './vehicle_chips2\\set1\\vehicle_chip_481.png',
#  './vehicle_chips2\\set1\\vehicle_chip_482.png',
#  './vehicle_chips2\\set1\\vehicle_chip_483.png',
#  './vehicle_chips2\\set1\\vehicle_chip_484.png',
#  './vehicle_chips2\\set1\\vehicle_chip_485.png',
#  './vehicle_chips2\\set1\\vehicle_chip_486.png',
#  './vehicle_chips2\\set1\\vehicle_chip_487.png',
#  './vehicle_chips2\\set1\\vehicle_chip_488.png',
#  './vehicle_chips2\\set1\\vehicle_chip_489.png',
#  './vehicle_chips2\\set1\\vehicle_chip_49.png',
#  './vehicle_chips2\\set1\\vehicle_chip_490.png',
#  './vehicle_chips2\\set1\\vehicle_chip_491.png',
#  './vehicle_chips2\\set1\\vehicle_chip_492.png',
#  './vehicle_chips2\\set1\\vehicle_chip_493.png',
#  './vehicle_chips2\\set1\\vehicle_chip_494.png',
#  './vehicle_chips2\\set1\\vehicle_chip_495.png',
#  './vehicle_chips2\\set1\\vehicle_chip_496.png',
#  './vehicle_chips2\\set1\\vehicle_chip_497.png',
#  './vehicle_chips2\\set1\\vehicle_chip_5.png',
#  './vehicle_chips2\\set1\\vehicle_chip_50.png',
#  './vehicle_chips2\\set1\\vehicle_chip_51.png',
#  './vehicle_chips2\\set1\\vehicle_chip_52.png',
#  './vehicle_chips2\\set1\\vehicle_chip_53.png',
#  './vehicle_chips2\\set1\\vehicle_chip_54.png',
#  './vehicle_chips2\\set1\\vehicle_chip_55.png',
#  './vehicle_chips2\\set1\\vehicle_chip_56.png',
#  './vehicle_chips2\\set1\\vehicle_chip_57.png',
#  './vehicle_chips2\\set1\\vehicle_chip_58.png',
#  './vehicle_chips2\\set1\\vehicle_chip_59.png',
#  './vehicle_chips2\\set1\\vehicle_chip_6.png',
#  './vehicle_chips2\\set1\\vehicle_chip_60.png',
#  './vehicle_chips2\\set1\\vehicle_chip_61.png',
#  './vehicle_chips2\\set1\\vehicle_chip_62.png',
#  './vehicle_chips2\\set1\\vehicle_chip_63.png',
#  './vehicle_chips2\\set1\\vehicle_chip_64.png',
#  './vehicle_chips2\\set1\\vehicle_chip_65.png',
#  './vehicle_chips2\\set1\\vehicle_chip_66.png',
#  './vehicle_chips2\\set1\\vehicle_chip_67.png',
#  './vehicle_chips2\\set1\\vehicle_chip_68.png',
#  './vehicle_chips2\\set1\\vehicle_chip_69.png',
#  './vehicle_chips2\\set1\\vehicle_chip_7.png',
#  './vehicle_chips2\\set1\\vehicle_chip_70.png',
#  './vehicle_chips2\\set1\\vehicle_chip_71.png',
#  './vehicle_chips2\\set1\\vehicle_chip_72.png',
#  './vehicle_chips2\\set1\\vehicle_chip_73.png',
#  './vehicle_chips2\\set1\\vehicle_chip_74.png',
#  './vehicle_chips2\\set1\\vehicle_chip_75.png',
#  './vehicle_chips2\\set1\\vehicle_chip_76.png',
#  './vehicle_chips2\\set1\\vehicle_chip_77.png',
#  './vehicle_chips2\\set1\\vehicle_chip_78.png',
#  './vehicle_chips2\\set1\\vehicle_chip_79.png',
#  './vehicle_chips2\\set1\\vehicle_chip_8.png',
#  './vehicle_chips2\\set1\\vehicle_chip_80.png',
#  './vehicle_chips2\\set1\\vehicle_chip_81.png',
#  './vehicle_chips2\\set1\\vehicle_chip_82.png',
#  './vehicle_chips2\\set1\\vehicle_chip_83.png',
#  './vehicle_chips2\\set1\\vehicle_chip_84.png',
#  './vehicle_chips2\\set1\\vehicle_chip_85.png',
#  './vehicle_chips2\\set1\\vehicle_chip_86.png',
#  './vehicle_chips2\\set1\\vehicle_chip_87.png',
#  './vehicle_chips2\\set1\\vehicle_chip_88.png',
#  './vehicle_chips2\\set1\\vehicle_chip_89.png',
#  './vehicle_chips2\\set1\\vehicle_chip_9.png',
#  './vehicle_chips2\\set1\\vehicle_chip_90.png',
#  './vehicle_chips2\\set1\\vehicle_chip_91.png',
#  './vehicle_chips2\\set1\\vehicle_chip_92.png',
#  './vehicle_chips2\\set1\\vehicle_chip_93.png',
#  './vehicle_chips2\\set1\\vehicle_chip_94.png',
#  './vehicle_chips2\\set1\\vehicle_chip_95.png',
#  './vehicle_chips2\\set1\\vehicle_chip_96.png',
#  './vehicle_chips2\\set1\\vehicle_chip_97.png',
#  './vehicle_chips2\\set1\\vehicle_chip_98.png',
#  './vehicle_chips2\\set1\\vehicle_chip_99.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3243.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3244.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3245.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3246.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3247.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3248.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3249.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3250.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3251.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3252.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3253.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3254.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3255.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3256.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3257.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3258.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3259.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3260.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3261.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3262.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3263.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3264.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3265.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3266.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3267.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3268.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3269.png',
#  './vehicle_chips2\\set2\\vehicle_chip_3270.png',
#  './vehicle_chips2\\set2\\vehicle_chip_498.png',
#  './vehicle_chips2\\set2\\vehicle_chip_499.png',
#  './vehicle_chips2\\set2\\vehicle_chip_500.png',
#  './vehicle_chips2\\set2\\vehicle_chip_501.png',
#  './vehicle_chips2\\set2\\vehicle_chip_502.png',
#  './vehicle_chips2\\set2\\vehicle_chip_503.png',
#  './vehicle_chips2\\set2\\vehicle_chip_504.png',
#  './vehicle_chips2\\set2\\vehicle_chip_505.png',
#  './vehicle_chips2\\set2\\vehicle_chip_506.png',
#  './vehicle_chips2\\set2\\vehicle_chip_507.png',
#  './vehicle_chips2\\set2\\vehicle_chip_508.png',
#  './vehicle_chips2\\set2\\vehicle_chip_509.png',
#  './vehicle_chips2\\set2\\vehicle_chip_510.png',
#  './vehicle_chips2\\set2\\vehicle_chip_511.png',
#  './vehicle_chips2\\set2\\vehicle_chip_512.png',
#  './vehicle_chips2\\set2\\vehicle_chip_513.png',
#  './vehicle_chips2\\set2\\vehicle_chip_514.png',
#  './vehicle_chips2\\set2\\vehicle_chip_515.png',
#  './vehicle_chips2\\set2\\vehicle_chip_516.png',
#  './vehicle_chips2\\set2\\vehicle_chip_517.png',
#  './vehicle_chips2\\set2\\vehicle_chip_518.png',
#  './vehicle_chips2\\set2\\vehicle_chip_519.png',
#  './vehicle_chips2\\set2\\vehicle_chip_520.png',
#  './vehicle_chips2\\set2\\vehicle_chip_521.png',
#  './vehicle_chips2\\set2\\vehicle_chip_522.png',
#  './vehicle_chips2\\set2\\vehicle_chip_523.png',
#  './vehicle_chips2\\set2\\vehicle_chip_524.png',
#  './vehicle_chips2\\set2\\vehicle_chip_525.png',
#  './vehicle_chips2\\set2\\vehicle_chip_526.png',
#  './vehicle_chips2\\set2\\vehicle_chip_527.png',
#  './vehicle_chips2\\set2\\vehicle_chip_528.png',
#  './vehicle_chips2\\set2\\vehicle_chip_529.png',
#  './vehicle_chips2\\set2\\vehicle_chip_530.png',
#  './vehicle_chips2\\set2\\vehicle_chip_531.png',
#  './vehicle_chips2\\set2\\vehicle_chip_532.png',
#  './vehicle_chips2\\set2\\vehicle_chip_533.png',
#  './vehicle_chips2\\set2\\vehicle_chip_534.png',
#  './vehicle_chips2\\set2\\vehicle_chip_535.png',
#  './vehicle_chips2\\set2\\vehicle_chip_536.png',
#  './vehicle_chips2\\set2\\vehicle_chip_537.png',
#  './vehicle_chips2\\set2\\vehicle_chip_538.png',
#  './vehicle_chips2\\set2\\vehicle_chip_539.png',
#  './vehicle_chips2\\set2\\vehicle_chip_540.png',
#  './vehicle_chips2\\set2\\vehicle_chip_541.png',
#  './vehicle_chips2\\set2\\vehicle_chip_542.png',
#  './vehicle_chips2\\set2\\vehicle_chip_543.png',
#  './vehicle_chips2\\set2\\vehicle_chip_544.png',
#  './vehicle_chips2\\set2\\vehicle_chip_545.png',
#  './vehicle_chips2\\set2\\vehicle_chip_546.png',
#  './vehicle_chips2\\set2\\vehicle_chip_547.png',
#  './vehicle_chips2\\set2\\vehicle_chip_548.png',
#  './vehicle_chips2\\set2\\vehicle_chip_549.png',
#  './vehicle_chips2\\set2\\vehicle_chip_550.png',
#  './vehicle_chips2\\set2\\vehicle_chip_551.png',
#  './vehicle_chips2\\set2\\vehicle_chip_552.png',
#  './vehicle_chips2\\set2\\vehicle_chip_553.png',
#  './vehicle_chips2\\set2\\vehicle_chip_554.png',
#  './vehicle_chips2\\set2\\vehicle_chip_555.png',
#  './vehicle_chips2\\set2\\vehicle_chip_556.png',
#  './vehicle_chips2\\set2\\vehicle_chip_557.png',
#  './vehicle_chips2\\set2\\vehicle_chip_558.png',
#  './vehicle_chips2\\set2\\vehicle_chip_559.png',
#  './vehicle_chips2\\set2\\vehicle_chip_560.png',
#  './vehicle_chips2\\set2\\vehicle_chip_561.png',
#  './vehicle_chips2\\set2\\vehicle_chip_562.png',
#  './vehicle_chips2\\set2\\vehicle_chip_563.png',
#  './vehicle_chips2\\set2\\vehicle_chip_564.png',
#  './vehicle_chips2\\set2\\vehicle_chip_565.png',
#  './vehicle_chips2\\set2\\vehicle_chip_566.png',
#  './vehicle_chips2\\set2\\vehicle_chip_567.png',
#  './vehicle_chips2\\set2\\vehicle_chip_568.png',
#  './vehicle_chips2\\set2\\vehicle_chip_569.png',
#  './vehicle_chips2\\set2\\vehicle_chip_570.png',
#  './vehicle_chips2\\set2\\vehicle_chip_571.png',
#  './vehicle_chips2\\set2\\vehicle_chip_572.png',
#  './vehicle_chips2\\set2\\vehicle_chip_573.png',
#  './vehicle_chips2\\set2\\vehicle_chip_574.png',
#  './vehicle_chips2\\set2\\vehicle_chip_575.png',
#  './vehicle_chips2\\set2\\vehicle_chip_576.png',
#  './vehicle_chips2\\set2\\vehicle_chip_577.png',
#  './vehicle_chips2\\set2\\vehicle_chip_578.png',
#  './vehicle_chips2\\set2\\vehicle_chip_579.png',
#  './vehicle_chips2\\set2\\vehicle_chip_580.png',
#  './vehicle_chips2\\set2\\vehicle_chip_581.png',
#  './vehicle_chips2\\set2\\vehicle_chip_582.png',
#  './vehicle_chips2\\set2\\vehicle_chip_583.png',
#  './vehicle_chips2\\set2\\vehicle_chip_584.png',
#  './vehicle_chips2\\set2\\vehicle_chip_585.png',
#  './vehicle_chips2\\set2\\vehicle_chip_586.png',
#  './vehicle_chips2\\set2\\vehicle_chip_587.png',
#  './vehicle_chips2\\set2\\vehicle_chip_588.png',
#  './vehicle_chips2\\set2\\vehicle_chip_589.png',
#  './vehicle_chips2\\set2\\vehicle_chip_590.png',
#  './vehicle_chips2\\set2\\vehicle_chip_591.png',
#  './vehicle_chips2\\set2\\vehicle_chip_592.png',
#  './vehicle_chips2\\set2\\vehicle_chip_593.png',
#  './vehicle_chips2\\set2\\vehicle_chip_594.png',
#  './vehicle_chips2\\set2\\vehicle_chip_595.png',
#  './vehicle_chips2\\set2\\vehicle_chip_596.png',
#  './vehicle_chips2\\set2\\vehicle_chip_597.png',
#  './vehicle_chips2\\set2\\vehicle_chip_598.png',
#  './vehicle_chips2\\set2\\vehicle_chip_599.png',
#  './vehicle_chips2\\set2\\vehicle_chip_600.png',
#  './vehicle_chips2\\set2\\vehicle_chip_601.png',
#  './vehicle_chips2\\set2\\vehicle_chip_602.png',
#  './vehicle_chips2\\set2\\vehicle_chip_603.png',
#  './vehicle_chips2\\set2\\vehicle_chip_604.png',
#  './vehicle_chips2\\set2\\vehicle_chip_605.png',
#  './vehicle_chips2\\set2\\vehicle_chip_606.png',
#  './vehicle_chips2\\set2\\vehicle_chip_607.png',
#  './vehicle_chips2\\set2\\vehicle_chip_608.png',
#  './vehicle_chips2\\set2\\vehicle_chip_609.png',
#  './vehicle_chips2\\set2\\vehicle_chip_610.png',
#  './vehicle_chips2\\set2\\vehicle_chip_611.png',
#  './vehicle_chips2\\set2\\vehicle_chip_612.png',
#  './vehicle_chips2\\set2\\vehicle_chip_613.png',
#  './vehicle_chips2\\set2\\vehicle_chip_614.png',
#  './vehicle_chips2\\set2\\vehicle_chip_615.png',
#  './vehicle_chips2\\set2\\vehicle_chip_616.png',
#  './vehicle_chips2\\set2\\vehicle_chip_617.png',
#  './vehicle_chips2\\set2\\vehicle_chip_618.png',
#  './vehicle_chips2\\set2\\vehicle_chip_619.png',
#  './vehicle_chips2\\set2\\vehicle_chip_620.png',
#  './vehicle_chips2\\set2\\vehicle_chip_621.png',
#  './vehicle_chips2\\set2\\vehicle_chip_622.png',
#  './vehicle_chips2\\set2\\vehicle_chip_623.png',
#  './vehicle_chips2\\set2\\vehicle_chip_624.png',
#  './vehicle_chips2\\set2\\vehicle_chip_625.png',
#  './vehicle_chips2\\set2\\vehicle_chip_626.png',
#  './vehicle_chips2\\set2\\vehicle_chip_627.png',
#  './vehicle_chips2\\set2\\vehicle_chip_628.png',
#  './vehicle_chips2\\set2\\vehicle_chip_629.png',
#  './vehicle_chips2\\set2\\vehicle_chip_630.png',
#  './vehicle_chips2\\set2\\vehicle_chip_631.png',
#  './vehicle_chips2\\set2\\vehicle_chip_632.png',
#  './vehicle_chips2\\set2\\vehicle_chip_633.png',
#  './vehicle_chips2\\set2\\vehicle_chip_634.png',
#  './vehicle_chips2\\set2\\vehicle_chip_635.png',
#  './vehicle_chips2\\set2\\vehicle_chip_636.png',
#  './vehicle_chips2\\set2\\vehicle_chip_637.png',
#  './vehicle_chips2\\set2\\vehicle_chip_638.png',
#  './vehicle_chips2\\set2\\vehicle_chip_639.png',
#  './vehicle_chips2\\set2\\vehicle_chip_640.png',
#  './vehicle_chips2\\set2\\vehicle_chip_641.png',
#  './vehicle_chips2\\set2\\vehicle_chip_642.png',
#  './vehicle_chips2\\set2\\vehicle_chip_643.png',
#  './vehicle_chips2\\set2\\vehicle_chip_644.png',
#  './vehicle_chips2\\set2\\vehicle_chip_645.png',
#  './vehicle_chips2\\set2\\vehicle_chip_646.png',
#  './vehicle_chips2\\set2\\vehicle_chip_647.png',
#  './vehicle_chips2\\set2\\vehicle_chip_648.png',
#  './vehicle_chips2\\set2\\vehicle_chip_649.png',
#  './vehicle_chips2\\set2\\vehicle_chip_650.png',
#  './vehicle_chips2\\set2\\vehicle_chip_651.png',
#  './vehicle_chips2\\set2\\vehicle_chip_652.png',
#  './vehicle_chips2\\set2\\vehicle_chip_653.png',
#  './vehicle_chips2\\set2\\vehicle_chip_654.png',
#  './vehicle_chips2\\set2\\vehicle_chip_655.png',
#  './vehicle_chips2\\set2\\vehicle_chip_656.png',
#  './vehicle_chips2\\set2\\vehicle_chip_657.png',
#  './vehicle_chips2\\set2\\vehicle_chip_658.png',
#  './vehicle_chips2\\set2\\vehicle_chip_659.png',
#  './vehicle_chips2\\set2\\vehicle_chip_660.png',
#  './vehicle_chips2\\set2\\vehicle_chip_661.png',
#  './vehicle_chips2\\set2\\vehicle_chip_662.png',
#  './vehicle_chips2\\set2\\vehicle_chip_663.png',
#  './vehicle_chips2\\set2\\vehicle_chip_664.png',
#  './vehicle_chips2\\set2\\vehicle_chip_665.png',
#  './vehicle_chips2\\set2\\vehicle_chip_666.png',
#  './vehicle_chips2\\set2\\vehicle_chip_667.png',
#  './vehicle_chips2\\set2\\vehicle_chip_668.png',
#  './vehicle_chips2\\set2\\vehicle_chip_669.png',
#  './vehicle_chips2\\set2\\vehicle_chip_670.png',
#  './vehicle_chips2\\set2\\vehicle_chip_671.png',
#  './vehicle_chips2\\set2\\vehicle_chip_672.png',
#  './vehicle_chips2\\set2\\vehicle_chip_673.png',
#  './vehicle_chips2\\set2\\vehicle_chip_674.png',
#  './vehicle_chips2\\set2\\vehicle_chip_675.png',
#  './vehicle_chips2\\set2\\vehicle_chip_676.png',
#  './vehicle_chips2\\set2\\vehicle_chip_677.png',
#  './vehicle_chips2\\set2\\vehicle_chip_678.png',
#  './vehicle_chips2\\set2\\vehicle_chip_679.png',
#  './vehicle_chips2\\set2\\vehicle_chip_680.png',
#  './vehicle_chips2\\set2\\vehicle_chip_681.png',
#  './vehicle_chips2\\set2\\vehicle_chip_682.png',
#  './vehicle_chips2\\set2\\vehicle_chip_683.png',
#  './vehicle_chips2\\set2\\vehicle_chip_684.png',
#  './vehicle_chips2\\set2\\vehicle_chip_685.png',
#  './vehicle_chips2\\set2\\vehicle_chip_686.png',
#  './vehicle_chips2\\set2\\vehicle_chip_687.png',
#  './vehicle_chips2\\set2\\vehicle_chip_688.png',
#  './vehicle_chips2\\set2\\vehicle_chip_689.png',
#  './vehicle_chips2\\set2\\vehicle_chip_690.png',
#  './vehicle_chips2\\set2\\vehicle_chip_691.png',
#  './vehicle_chips2\\set2\\vehicle_chip_692.png',
#  './vehicle_chips2\\set2\\vehicle_chip_693.png',
#  './vehicle_chips2\\set2\\vehicle_chip_694.png',
#  './vehicle_chips2\\set2\\vehicle_chip_695.png',
#  './vehicle_chips2\\set2\\vehicle_chip_696.png',
#  './vehicle_chips2\\set2\\vehicle_chip_697.png',
#  './vehicle_chips2\\set2\\vehicle_chip_698.png',
#  './vehicle_chips2\\set2\\vehicle_chip_699.png',
#  './vehicle_chips2\\set2\\vehicle_chip_700.png',
#  './vehicle_chips2\\set2\\vehicle_chip_701.png',
#  './vehicle_chips2\\set2\\vehicle_chip_702.png',
#  './vehicle_chips2\\set2\\vehicle_chip_703.png',
#  './vehicle_chips2\\set2\\vehicle_chip_704.png',
#  './vehicle_chips2\\set2\\vehicle_chip_705.png',
#  './vehicle_chips2\\set2\\vehicle_chip_706.png',
#  './vehicle_chips2\\set2\\vehicle_chip_707.png',
#  './vehicle_chips2\\set2\\vehicle_chip_708.png',
#  './vehicle_chips2\\set2\\vehicle_chip_709.png',
#  './vehicle_chips2\\set2\\vehicle_chip_710.png',
#  './vehicle_chips2\\set2\\vehicle_chip_711.png',
#  './vehicle_chips2\\set2\\vehicle_chip_712.png',
#  './vehicle_chips2\\set2\\vehicle_chip_713.png',
#  './vehicle_chips2\\set2\\vehicle_chip_714.png',
#  './vehicle_chips2\\set2\\vehicle_chip_715.png',
#  './vehicle_chips2\\set2\\vehicle_chip_716.png',
#  './vehicle_chips2\\set2\\vehicle_chip_717.png',
#  './vehicle_chips2\\set2\\vehicle_chip_718.png',
#  './vehicle_chips2\\set2\\vehicle_chip_719.png',
#  './vehicle_chips2\\set2\\vehicle_chip_720.png',
#  './vehicle_chips2\\set2\\vehicle_chip_721.png',
#  './vehicle_chips2\\set2\\vehicle_chip_722.png',
#  './vehicle_chips2\\set2\\vehicle_chip_723.png',
#  './vehicle_chips2\\set2\\vehicle_chip_724.png',
#  './vehicle_chips2\\set2\\vehicle_chip_725.png',
#  './vehicle_chips2\\set2\\vehicle_chip_726.png',
#  './vehicle_chips2\\set2\\vehicle_chip_727.png',
#  './vehicle_chips2\\set2\\vehicle_chip_728.png',
#  './vehicle_chips2\\set2\\vehicle_chip_729.png',
#  './vehicle_chips2\\set2\\vehicle_chip_730.png',
#  './vehicle_chips2\\set2\\vehicle_chip_731.png',
#  './vehicle_chips2\\set2\\vehicle_chip_732.png',
#  './vehicle_chips2\\set2\\vehicle_chip_733.png',
#  './vehicle_chips2\\set2\\vehicle_chip_734.png',
#  './vehicle_chips2\\set2\\vehicle_chip_735.png',
#  './vehicle_chips2\\set2\\vehicle_chip_736.png',
#  './vehicle_chips2\\set2\\vehicle_chip_737.png',
#  './vehicle_chips2\\set2\\vehicle_chip_738.png',
#  './vehicle_chips2\\set2\\vehicle_chip_739.png',
#  './vehicle_chips2\\set2\\vehicle_chip_740.png',
#  './vehicle_chips2\\set2\\vehicle_chip_741.png',
#  './vehicle_chips2\\set2\\vehicle_chip_742.png',
#  './vehicle_chips2\\set2\\vehicle_chip_743.png',
#  './vehicle_chips2\\set2\\vehicle_chip_744.png',
#  './vehicle_chips2\\set2\\vehicle_chip_745.png',
#  './vehicle_chips2\\set2\\vehicle_chip_746.png',
#  './vehicle_chips2\\set2\\vehicle_chip_747.png',
#  './vehicle_chips2\\set2\\vehicle_chip_748.png',
#  './vehicle_chips2\\set2\\vehicle_chip_749.png',
#  './vehicle_chips2\\set2\\vehicle_chip_750.png',
#  './vehicle_chips2\\set2\\vehicle_chip_751.png',
#  './vehicle_chips2\\set2\\vehicle_chip_752.png',
#  './vehicle_chips2\\set2\\vehicle_chip_753.png',
#  './vehicle_chips2\\set2\\vehicle_chip_754.png',
#  './vehicle_chips2\\set2\\vehicle_chip_755.png',
#  './vehicle_chips2\\set2\\vehicle_chip_756.png',
#  './vehicle_chips2\\set2\\vehicle_chip_757.png',
#  './vehicle_chips2\\set2\\vehicle_chip_758.png',
#  './vehicle_chips2\\set2\\vehicle_chip_759.png',
#  './vehicle_chips2\\set2\\vehicle_chip_760.png',
#  './vehicle_chips2\\set2\\vehicle_chip_761.png',
#  './vehicle_chips2\\set2\\vehicle_chip_762.png',
#  './vehicle_chips2\\set2\\vehicle_chip_763.png',
#  './vehicle_chips2\\set2\\vehicle_chip_764.png',
#  './vehicle_chips2\\set2\\vehicle_chip_765.png',
#  './vehicle_chips2\\set2\\vehicle_chip_766.png',
#  './vehicle_chips2\\set2\\vehicle_chip_767.png',
#  './vehicle_chips2\\set2\\vehicle_chip_768.png',
#  './vehicle_chips2\\set2\\vehicle_chip_769.png',
#  './vehicle_chips2\\set2\\vehicle_chip_770.png',
#  './vehicle_chips2\\set2\\vehicle_chip_771.png',
#  './vehicle_chips2\\set2\\vehicle_chip_772.png',
#  './vehicle_chips2\\set2\\vehicle_chip_773.png',
#  './vehicle_chips2\\set2\\vehicle_chip_774.png',
#  './vehicle_chips2\\set2\\vehicle_chip_775.png',
#  './vehicle_chips2\\set2\\vehicle_chip_776.png',
#  './vehicle_chips2\\set2\\vehicle_chip_777.png',
#  './vehicle_chips2\\set2\\vehicle_chip_778.png',
#  './vehicle_chips2\\set2\\vehicle_chip_779.png',
#  './vehicle_chips2\\set2\\vehicle_chip_780.png',
#  './vehicle_chips2\\set2\\vehicle_chip_781.png',
#  './vehicle_chips2\\set2\\vehicle_chip_782.png',
#  './vehicle_chips2\\set2\\vehicle_chip_783.png',
#  './vehicle_chips2\\set2\\vehicle_chip_784.png',
#  './vehicle_chips2\\set2\\vehicle_chip_785.png',
#  './vehicle_chips2\\set2\\vehicle_chip_786.png',
#  './vehicle_chips2\\set2\\vehicle_chip_787.png',
#  './vehicle_chips2\\set2\\vehicle_chip_788.png',
#  './vehicle_chips2\\set2\\vehicle_chip_789.png',
#  './vehicle_chips2\\set2\\vehicle_chip_790.png',
#  './vehicle_chips2\\set2\\vehicle_chip_791.png',
#  './vehicle_chips2\\set2\\vehicle_chip_792.png',
#  './vehicle_chips2\\set2\\vehicle_chip_793.png',
#  './vehicle_chips2\\set2\\vehicle_chip_794.png',
#  './vehicle_chips2\\set2\\vehicle_chip_795.png',
#  './vehicle_chips2\\set2\\vehicle_chip_796.png',
#  './vehicle_chips2\\set2\\vehicle_chip_797.png',
#  './vehicle_chips2\\set2\\vehicle_chip_798.png',
#  './vehicle_chips2\\set2\\vehicle_chip_799.png',
#  './vehicle_chips2\\set2\\vehicle_chip_800.png',
#  './vehicle_chips2\\set2\\vehicle_chip_801.png',
#  './vehicle_chips2\\set2\\vehicle_chip_802.png',
#  './vehicle_chips2\\set2\\vehicle_chip_803.png',
#  './vehicle_chips2\\set2\\vehicle_chip_804.png',
#  './vehicle_chips2\\set2\\vehicle_chip_805.png',
#  './vehicle_chips2\\set2\\vehicle_chip_806.png',
#  './vehicle_chips2\\set2\\vehicle_chip_807.png',
#  './vehicle_chips2\\set2\\vehicle_chip_808.png',
#  './vehicle_chips2\\set2\\vehicle_chip_809.png',
#  './vehicle_chips2\\set2\\vehicle_chip_810.png',
#  './vehicle_chips2\\set2\\vehicle_chip_811.png',
#  './vehicle_chips2\\set2\\vehicle_chip_812.png',
#  './vehicle_chips2\\set2\\vehicle_chip_813.png',
#  './vehicle_chips2\\set2\\vehicle_chip_814.png',
#  './vehicle_chips2\\set2\\vehicle_chip_815.png',
#  './vehicle_chips2\\set2\\vehicle_chip_816.png',
#  './vehicle_chips2\\set2\\vehicle_chip_817.png',
#  './vehicle_chips2\\set2\\vehicle_chip_818.png',
#  './vehicle_chips2\\set2\\vehicle_chip_819.png',
#  './vehicle_chips2\\set2\\vehicle_chip_820.png',
#  './vehicle_chips2\\set2\\vehicle_chip_821.png',
#  './vehicle_chips2\\set2\\vehicle_chip_822.png',
#  './vehicle_chips2\\set2\\vehicle_chip_823.png',
#  './vehicle_chips2\\set2\\vehicle_chip_824.png',
#  './vehicle_chips2\\set2\\vehicle_chip_825.png',
#  './vehicle_chips2\\set2\\vehicle_chip_826.png',
#  './vehicle_chips2\\set2\\vehicle_chip_827.png',
#  './vehicle_chips2\\set2\\vehicle_chip_828.png',
#  './vehicle_chips2\\set2\\vehicle_chip_829.png',
#  './vehicle_chips2\\set2\\vehicle_chip_830.png',
#  './vehicle_chips2\\set2\\vehicle_chip_831.png',
#  './vehicle_chips2\\set2\\vehicle_chip_832.png',
#  './vehicle_chips2\\set2\\vehicle_chip_833.png',
#  './vehicle_chips2\\set2\\vehicle_chip_834.png',
#  './vehicle_chips2\\set2\\vehicle_chip_835.png',
#  './vehicle_chips2\\set2\\vehicle_chip_836.png',
#  './vehicle_chips2\\set2\\vehicle_chip_837.png',
#  './vehicle_chips2\\set2\\vehicle_chip_838.png',
#  './vehicle_chips2\\set2\\vehicle_chip_839.png',
#  './vehicle_chips2\\set2\\vehicle_chip_840.png',
#  './vehicle_chips2\\set2\\vehicle_chip_841.png',
#  './vehicle_chips2\\set2\\vehicle_chip_842.png',
#  './vehicle_chips2\\set2\\vehicle_chip_843.png',
#  './vehicle_chips2\\set2\\vehicle_chip_844.png',
#  './vehicle_chips2\\set2\\vehicle_chip_845.png',
#  './vehicle_chips2\\set2\\vehicle_chip_846.png',
#  './vehicle_chips2\\set2\\vehicle_chip_847.png',
#  './vehicle_chips2\\set2\\vehicle_chip_848.png',
#  './vehicle_chips2\\set2\\vehicle_chip_849.png',
#  './vehicle_chips2\\set2\\vehicle_chip_850.png',
#  './vehicle_chips2\\set2\\vehicle_chip_851.png',
#  './vehicle_chips2\\set2\\vehicle_chip_852.png',
#  './vehicle_chips2\\set2\\vehicle_chip_853.png',
#  './vehicle_chips2\\set2\\vehicle_chip_854.png',
#  './vehicle_chips2\\set2\\vehicle_chip_855.png',
#  './vehicle_chips2\\set2\\vehicle_chip_856.png',
#  './vehicle_chips2\\set2\\vehicle_chip_857.png',
#  './vehicle_chips2\\set2\\vehicle_chip_858.png',
#  './vehicle_chips2\\set2\\vehicle_chip_859.png',
#  './vehicle_chips2\\set2\\vehicle_chip_860.png',
#  './vehicle_chips2\\set2\\vehicle_chip_861.png',
#  './vehicle_chips2\\set2\\vehicle_chip_862.png',
#  './vehicle_chips2\\set2\\vehicle_chip_863.png',
#  './vehicle_chips2\\set2\\vehicle_chip_864.png',
#  './vehicle_chips2\\set2\\vehicle_chip_865.png',
#  './vehicle_chips2\\set2\\vehicle_chip_866.png',
#  './vehicle_chips2\\set2\\vehicle_chip_867.png',
#  './vehicle_chips2\\set2\\vehicle_chip_868.png',
#  './vehicle_chips2\\set2\\vehicle_chip_869.png',
#  './vehicle_chips2\\set2\\vehicle_chip_870.png',
#  './vehicle_chips2\\set2\\vehicle_chip_871.png',
#  './vehicle_chips2\\set2\\vehicle_chip_872.png',
#  './vehicle_chips2\\set2\\vehicle_chip_873.png',
#  './vehicle_chips2\\set2\\vehicle_chip_874.png',
#  './vehicle_chips2\\set2\\vehicle_chip_875.png',
#  './vehicle_chips2\\set2\\vehicle_chip_876.png',
#  './vehicle_chips2\\set2\\vehicle_chip_877.png',
#  './vehicle_chips2\\set2\\vehicle_chip_878.png',
#  './vehicle_chips2\\set2\\vehicle_chip_879.png',
#  './vehicle_chips2\\set2\\vehicle_chip_880.png',
#  './vehicle_chips2\\set2\\vehicle_chip_881.png',
#  './vehicle_chips2\\set2\\vehicle_chip_882.png',
#  './vehicle_chips2\\set2\\vehicle_chip_883.png',
#  './vehicle_chips2\\set2\\vehicle_chip_884.png',
#  './vehicle_chips2\\set2\\vehicle_chip_885.png',
#  './vehicle_chips2\\set2\\vehicle_chip_886.png',
#  './vehicle_chips2\\set2\\vehicle_chip_887.png',
#  './vehicle_chips2\\set2\\vehicle_chip_888.png',
#  './vehicle_chips2\\set2\\vehicle_chip_889.png',
#  './vehicle_chips2\\set2\\vehicle_chip_890.png',
#  './vehicle_chips2\\set2\\vehicle_chip_891.png',
#  './vehicle_chips2\\set2\\vehicle_chip_892.png',
#  './vehicle_chips2\\set2\\vehicle_chip_893.png',
#  './vehicle_chips2\\set2\\vehicle_chip_894.png',
#  './vehicle_chips2\\set2\\vehicle_chip_895.png',
#  './vehicle_chips2\\set2\\vehicle_chip_896.png',
#  './vehicle_chips2\\set2\\vehicle_chip_897.png',
#  './vehicle_chips2\\set2\\vehicle_chip_898.png',
#  './vehicle_chips2\\set2\\vehicle_chip_899.png',
#  './vehicle_chips2\\set2\\vehicle_chip_900.png',
#  './vehicle_chips2\\set2\\vehicle_chip_901.png',
#  './vehicle_chips2\\set2\\vehicle_chip_902.png',
#  './vehicle_chips2\\set2\\vehicle_chip_903.png',
#  './vehicle_chips2\\set2\\vehicle_chip_904.png',
#  './vehicle_chips2\\set2\\vehicle_chip_905.png',
#  './vehicle_chips2\\set2\\vehicle_chip_906.png',
#  './vehicle_chips2\\set2\\vehicle_chip_907.png',
#  './vehicle_chips2\\set2\\vehicle_chip_908.png',
#  './vehicle_chips2\\set2\\vehicle_chip_909.png',
#  './vehicle_chips2\\set2\\vehicle_chip_910.png',
#  './vehicle_chips2\\set2\\vehicle_chip_911.png',
#  './vehicle_chips2\\set2\\vehicle_chip_912.png',
#  './vehicle_chips2\\set2\\vehicle_chip_913.png',
#  './vehicle_chips2\\set2\\vehicle_chip_914.png',
#  './vehicle_chips2\\set2\\vehicle_chip_915.png',
#  './vehicle_chips2\\set2\\vehicle_chip_916.png',
#  './vehicle_chips2\\set2\\vehicle_chip_917.png',
#  './vehicle_chips2\\set2\\vehicle_chip_918.png',
#  './vehicle_chips2\\set2\\vehicle_chip_919.png',
#  './vehicle_chips2\\set2\\vehicle_chip_920.png',
#  './vehicle_chips2\\set2\\vehicle_chip_921.png',
#  './vehicle_chips2\\set2\\vehicle_chip_922.png',
#  './vehicle_chips2\\set2\\vehicle_chip_923.png',
#  './vehicle_chips2\\set2\\vehicle_chip_924.png',
#  './vehicle_chips2\\set2\\vehicle_chip_925.png',
#  './vehicle_chips2\\set2\\vehicle_chip_926.png',
#  './vehicle_chips2\\set2\\vehicle_chip_927.png',
#  './vehicle_chips2\\set2\\vehicle_chip_928.png',
#  './vehicle_chips2\\set2\\vehicle_chip_929.png',
#  './vehicle_chips2\\set2\\vehicle_chip_930.png',
#  './vehicle_chips2\\set2\\vehicle_chip_931.png',
#  './vehicle_chips2\\set2\\vehicle_chip_932.png',
#  './vehicle_chips2\\set2\\vehicle_chip_933.png',
#  './vehicle_chips2\\set2\\vehicle_chip_934.png',
#  './vehicle_chips2\\set2\\vehicle_chip_935.png',
#  './vehicle_chips2\\set2\\vehicle_chip_936.png',
#  './vehicle_chips2\\set2\\vehicle_chip_937.png',
#  './vehicle_chips2\\set2\\vehicle_chip_938.png',
#  './vehicle_chips2\\set2\\vehicle_chip_939.png',
#  './vehicle_chips2\\set2\\vehicle_chip_940.png',
#  './vehicle_chips2\\set2\\vehicle_chip_941.png',
#  './vehicle_chips2\\set2\\vehicle_chip_942.png',
#  './vehicle_chips2\\set2\\vehicle_chip_943.png',
#  './vehicle_chips2\\set2\\vehicle_chip_944.png',
#  './vehicle_chips2\\set2\\vehicle_chip_945.png',
#  './vehicle_chips2\\set2\\vehicle_chip_946.png',
#  './vehicle_chips2\\set2\\vehicle_chip_947.png',
#  './vehicle_chips2\\set2\\vehicle_chip_948.png',
#  './vehicle_chips2\\set2\\vehicle_chip_949.png',
#  './vehicle_chips2\\set2\\vehicle_chip_950.png',
#  './vehicle_chips2\\set2\\vehicle_chip_951.png',
#  './vehicle_chips2\\set2\\vehicle_chip_952.png',
#  './vehicle_chips2\\set2\\vehicle_chip_953.png',
#  './vehicle_chips2\\set2\\vehicle_chip_954.png',
#  './vehicle_chips2\\set2\\vehicle_chip_955.png',
#  './vehicle_chips2\\set2\\vehicle_chip_956.png',
#  './vehicle_chips2\\set2\\vehicle_chip_957.png',
#  './vehicle_chips2\\set2\\vehicle_chip_958.png',
#  './vehicle_chips2\\set2\\vehicle_chip_959.png',
#  './vehicle_chips2\\set2\\vehicle_chip_960.png',
#  './vehicle_chips2\\set2\\vehicle_chip_961.png',
#  './vehicle_chips2\\set2\\vehicle_chip_962.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1000.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1001.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1002.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1003.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1004.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1005.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1006.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1007.png',
#  './vehicle_chips2\\set3\\vehicle_chip_1008.png',
#  ...]

# %%
len(vehicle_images)
# Out:
# 3271

# %%
vehicle_labels = np.ones(shape = (3271))
vehicle_labels = vehicle_labels.astype('uint8')

# %%
full_set = list(zip(vehicle_images, vehicle_labels))

# %%
df = pd.DataFrame(full_set, columns = ['image_names', 'vehicle_or_not'])
df.head()
# Out:
#                                   image_names  vehicle_or_not
# 0    ./vehicle_chips2\set1\vehicle_chip_0.png               1
# 1    ./vehicle_chips2\set1\vehicle_chip_1.png               1
# 2   ./vehicle_chips2\set1\vehicle_chip_10.png               1
# 3  ./vehicle_chips2\set1\vehicle_chip_100.png               1
# 4  ./vehicle_chips2\set1\vehicle_chip_101.png               1

# %%
tree_images = glob.glob('./tree_chips2/*/*.png')

# %%
len(tree_images)
# Out:
# 1925

# %%
tree_labels = np.zeros(shape = (1925))
tree_labels = tree_labels.astype('uint8')

# %%
tree_set = list(zip(tree_images, tree_labels))

# %%
df = df.append(pd.DataFrame(tree_set, columns = ['image_names', 'vehicle_or_not'])).reset_index()

# %%
df = df[['image_names','vehicle_or_not']]

# %%
df
# Out:
#                                      image_names  vehicle_or_not
# 0       ./vehicle_chips2\set1\vehicle_chip_0.png               1
# 1       ./vehicle_chips2\set1\vehicle_chip_1.png               1
# 2      ./vehicle_chips2\set1\vehicle_chip_10.png               1
# 3     ./vehicle_chips2\set1\vehicle_chip_100.png               1
# 4     ./vehicle_chips2\set1\vehicle_chip_101.png               1
# ...                                          ...             ...
# 5191       ./tree_chips2\set4\tree_chip_1920.png               0
# 5192       ./tree_chips2\set4\tree_chip_1921.png               0
# 5193       ./tree_chips2\set4\tree_chip_1922.png               0
# 5194       ./tree_chips2\set4\tree_chip_1923.png               0
# 5195       ./tree_chips2\set4\tree_chip_1924.png               0
#
# [5196 rows x 2 columns]

# %%
# Split data into train-test data sets

X = df.loc[:,'image_names']
y = df.loc[:,'vehicle_or_not']

# Split
train_x, val_x, train_y, val_y = train_test_split(X, y, 
                                                  test_size = 0.1, 
                                                  random_state = 27, 
                                                  stratify=y)

# Train df
df_train = pd.DataFrame(columns=['image_name','category'])
df_train['image_name'] = train_x
df_train['category'] = train_y

# Test df
df_test= pd.DataFrame(columns=['image_name','category'])
df_test['image_name'] = val_x
df_test['category'] = val_y

df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

# %%
df_train
# Out:
#                                        image_name  category
# 0     ./vehicle_chips2\set4\vehicle_chip_1538.png         1
# 1             ./tree_chips2\set1\tree_chip_82.png         0
# 2           ./tree_chips2\set4\tree_chip_1654.png         0
# 3     ./vehicle_chips2\set7\vehicle_chip_3237.png         1
# 4     ./vehicle_chips2\set6\vehicle_chip_2660.png         1
# ...                                           ...       ...
# 4671         ./tree_chips2\set2\tree_chip_740.png         0
# 4672           ./tree_chips2\set1\tree_chip_2.png         0
# 4673  ./vehicle_chips2\set5\vehicle_chip_1814.png         1
# 4674  ./vehicle_chips2\set7\vehicle_chip_2977.png         1
# 4675   ./vehicle_chips2\set1\vehicle_chip_472.png         1
#
# [4676 rows x 2 columns]

# %%
df_test
# Out:
#                                       image_name  category
# 0           ./tree_chips2\set2\tree_chip_815.png         0
# 1     ./vehicle_chips2\set2\vehicle_chip_777.png         1
# 2          ./tree_chips2\set3\tree_chip_1212.png         0
# 3           ./tree_chips2\set2\tree_chip_536.png         0
# 4    ./vehicle_chips2\set7\vehicle_chip_3061.png         1
# ..                                           ...       ...
# 515  ./vehicle_chips2\set5\vehicle_chip_2237.png         1
# 516  ./vehicle_chips2\set4\vehicle_chip_1547.png         1
# 517  ./vehicle_chips2\set7\vehicle_chip_2973.png         1
# 518        ./tree_chips2\set4\tree_chip_1608.png         0
# 519  ./vehicle_chips2\set6\vehicle_chip_2648.png         1
#
# [520 rows x 2 columns]

# %%
# Images
train_images = df_train.loc[:,'image_name']
train_labels = df_train.loc[:,'category']

test_images = df_test.loc[:,'image_name']
test_labels = df_test.loc[:,'category']

# Train images
x_train = []
for i in train_images:
    img = cv2.imread(i)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    x_train.append(img)

# Train labels
y_train=tf.keras.utils.to_categorical(train_labels)

# Test images
x_test = []
for i in test_images:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    x_test.append(img)

# Test labels
y_test=tf.keras.utils.to_categorical(test_labels)

# Normalize images
x_train = np.array(x_train, dtype="float") / 255.0
x_test = np.array(x_test, dtype="float") / 255.0

# %%
x_train.shape
# Out:
# (4676, 24, 24, 3)

# %%
x_train[0]
# Out:
# array([[[0.62745098, 0.63137255, 0.61960784],
#         [0.62745098, 0.63529412, 0.62352941],
#         [0.62745098, 0.63529412, 0.62352941],
#         ...,
#         [0.70196078, 0.70196078, 0.6627451 ],
#         [0.69803922, 0.69019608, 0.65098039],
#         [0.69411765, 0.68235294, 0.64313725]],
#
#        [[0.61176471, 0.61568627, 0.60392157],
#         [0.61960784, 0.62745098, 0.61568627],
#         [0.62745098, 0.63529412, 0.62352941],
#         ...,
#         [0.70588235, 0.70588235, 0.65882353],
#         [0.68235294, 0.6745098 , 0.62745098],
#         [0.65490196, 0.64313725, 0.59607843]],
#
#        [[0.59607843, 0.6       , 0.58823529],
#         [0.61568627, 0.62352941, 0.61176471],
#         [0.63529412, 0.64705882, 0.63529412],
#         ...,
#         [0.61960784, 0.61960784, 0.56470588],
#         [0.63137255, 0.62352941, 0.56862745],
#         [0.64313725, 0.63137255, 0.57254902]],
#
#        ...,
#
#        [[0.63529412, 0.62745098, 0.58039216],
#         [0.63921569, 0.63529412, 0.58823529],
#         [0.64705882, 0.64705882, 0.60392157],
#         ...,
#         [0.56470588, 0.57647059, 0.56078431],
#         [0.56470588, 0.56862745, 0.55294118],
#         [0.55686275, 0.55686275, 0.54117647]],
#
#        [[0.62745098, 0.61960784, 0.57254902],
#         [0.63529412, 0.63137255, 0.58431373],
#         [0.64313725, 0.64313725, 0.6       ],
#         ...,
#         [0.56470588, 0.57647059, 0.56078431],
#         [0.55686275, 0.56078431, 0.54509804],
#         [0.54117647, 0.54117647, 0.5254902 ]],
#
#        [[0.62745098, 0.61568627, 0.56862745],
#         [0.63529412, 0.62745098, 0.58039216],
#         [0.64705882, 0.64313725, 0.6       ],
#         ...,
#         [0.56862745, 0.57647059, 0.56078431],
#         [0.54901961, 0.55294118, 0.5372549 ],
#         [0.5254902 , 0.5254902 , 0.50980392]]])

# %%
x_test.shape
# Out:
# (520, 24, 24, 3)

# %%
y_train[0]
# Out:
# array([0., 1.], dtype=float32)

# %%
y_train.shape
# Out:
# (4676, 2)

# %%
y_test.shape
# Out:
# (520, 2)

# %%
# Model architechture
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(24, 24, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.24))
model.add(Dense(2,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 22, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 32)          9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 64)          18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 32,930
# Trainable params: 32,930
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile
optim = tf.keras.optimizers.RMSprop(learning_rate=0.00001)
model.compile(loss='categorical_crossentropy',
              optimizer=optim,
              metrics=['accuracy'])

# %%
# Augmentation
train_datagen = ImageDataGenerator(rotation_range=5,  # rotation
                                   width_shift_range=0.2,  # horizontal shift
                                   zoom_range=0.2,  # zoom
                                   horizontal_flip=True,  # horizontal flip
                                   brightness_range=[0.2,0.8],
                                    )  # brightness

# %%
# Epochs
epochs = 25
# Batch size
batch_size = 32

history = model.fit(train_datagen.flow(x_train,y_train,
                                       batch_size=batch_size, 
                                       seed=27,
                                       shuffle=False,
                                      save_to_dir = './created_images',
                                      save_prefix = 'created',
                                      save_format = 'png'),
                    epochs=epochs,
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    validation_data=(x_test,y_test),
                    verbose=1)
# Out:
# Epoch 1/25
# 146/146 [==============================] - 5s 36ms/step - loss: 1.9218 - accuracy: 0.5241 - val_loss: 0.6934 - val_accuracy: 0.4904
# Epoch 2/25
# 146/146 [==============================] - 5s 33ms/step - loss: 0.9927 - accuracy: 0.6324 - val_loss: 0.6930 - val_accuracy: 0.5096
# Epoch 3/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.5557 - accuracy: 0.7644 - val_loss: 0.6937 - val_accuracy: 0.5096
# Epoch 4/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.3893 - accuracy: 0.8359 - val_loss: 0.6949 - val_accuracy: 0.3712
# Epoch 5/25
# 146/146 [==============================] - 5s 36ms/step - loss: 0.2643 - accuracy: 0.8981 - val_loss: 0.6960 - val_accuracy: 0.3712
# Epoch 6/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.2152 - accuracy: 0.9294 - val_loss: 0.6967 - val_accuracy: 0.3712
# Epoch 7/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.1769 - accuracy: 0.9434 - val_loss: 0.6981 - val_accuracy: 0.3712
# Epoch 8/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.1389 - accuracy: 0.9563 - val_loss: 0.6988 - val_accuracy: 0.3712
# Epoch 9/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.1218 - accuracy: 0.9666 - val_loss: 0.6993 - val_accuracy: 0.3712
# Epoch 10/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.1001 - accuracy: 0.9716 - val_loss: 0.6994 - val_accuracy: 0.3712
# Epoch 11/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.0893 - accuracy: 0.9720 - val_loss: 0.6993 - val_accuracy: 0.3712
# Epoch 12/25
# 146/146 [==============================] - 5s 36ms/step - loss: 0.0803 - accuracy: 0.9776 - val_loss: 0.7005 - val_accuracy: 0.3712
# Epoch 13/25
# 146/146 [==============================] - 5s 37ms/step - loss: 0.0610 - accuracy: 0.9813 - val_loss: 0.7001 - val_accuracy: 0.3712
# Epoch 14/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.0620 - accuracy: 0.9819 - val_loss: 0.7012 - val_accuracy: 0.3712
# Epoch 15/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.0590 - accuracy: 0.9839 - val_loss: 0.7007 - val_accuracy: 0.3712
# Epoch 16/25
# 146/146 [==============================] - 5s 36ms/step - loss: 0.0523 - accuracy: 0.9864 - val_loss: 0.7006 - val_accuracy: 0.3712
# Epoch 17/25
# 146/146 [==============================] - 6s 38ms/step - loss: 0.0503 - accuracy: 0.9866 - val_loss: 0.7019 - val_accuracy: 0.3712
# Epoch 18/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.0481 - accuracy: 0.9849 - val_loss: 0.7015 - val_accuracy: 0.3712
# Epoch 19/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.0485 - accuracy: 0.9869 - val_loss: 0.7028 - val_accuracy: 0.3712
# Epoch 20/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.0478 - accuracy: 0.9856 - val_loss: 0.7027 - val_accuracy: 0.3712
# Epoch 21/25
# 146/146 [==============================] - 5s 37ms/step - loss: 0.0443 - accuracy: 0.9875 - val_loss: 0.7032 - val_accuracy: 0.3712
# Epoch 22/25
# 146/146 [==============================] - 5s 36ms/step - loss: 0.0422 - accuracy: 0.9892 - val_loss: 0.7028 - val_accuracy: 0.3712
# Epoch 23/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.0466 - accuracy: 0.9869 - val_loss: 0.7023 - val_accuracy: 0.3712
# Epoch 24/25
# 146/146 [==============================] - 5s 35ms/step - loss: 0.0439 - accuracy: 0.9869 - val_loss: 0.7035 - val_accuracy: 0.3712
# Epoch 25/25
# 146/146 [==============================] - 5s 34ms/step - loss: 0.0388 - accuracy: 0.9886 - val_loss: 0.7031 - val_accuracy: 0.3712

# %%
plt.plot(history.history['loss'], 'r')
plt.plot(history.history['accuracy'], 'b')
plt.show()

# %%
plt.plot(history.history['val_loss'], 'r')
plt.plot(history.history['val_accuracy'], 'b')
plt.show()

# %%
im = cv2.imread('./created_images/created_9_372.png')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
'''
cv2.imshow('image', im)
cv2.waitKey(0)
cv2.destroyAllWindows()
'''
# Out:
# "\ncv2.imshow('image', im)\ncv2.waitKey(0)\ncv2.destroyAllWindows()\n"

# %%
plt.imshow(im)
